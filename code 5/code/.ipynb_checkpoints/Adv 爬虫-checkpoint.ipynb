# %% [markdown]
# ## 认证授权

# %%
import requests

# %% [markdown]
# ### cookie- based

# %%
url = 'http://httpbin.org/cookies'
cookies = dict(cookies_are='working')
r = requests.get(url, cookies=cookies)
r.text

# %% [markdown]
# Cookies are returned in a RequestsCookieJar, which acts like a dict but also offers a more complete interface, suitable for use over multiple domains or paths. Cookie jars can also be passed in to requests:

# %%
r = requests.get("http://i.baidu.com/")

# %%
r.text
# Out:
# '<!doctype html>\n<html>\n<head>\n    <meta charset="UTF-8">\n    <!-- <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" /> -->\n    <title>百度个人中心——您在百度的家</title>\n    <meta name="description" content="百度个人中心是百度用户管理个性化信息的平台，在这里，您可以体验贴吧的交流、知道的解答、百科的全面、空间的个性、云盘的强大……感受百度为您带来的方便、快捷与乐趣。">\n    <meta name="keywords" content="个人中心,个人主页,个人帐号,个人空间">\n    <meta name="baidu-site-verification" content="qo9ZiURIQf" />\n    <!--[if lt IE 7]>\n    <script>\n        window.location.href = \'http://i.baidu.com/static/ieup/index.html\';\n    </script>\n    <![endif]-->\n    <link rel="shortcut icon" type="image/ico" href="http://www.baidu.com/favicon.ico" />\n    <link rel="stylesheet" href="http://uc-vs.bdimg.com/v3/20150603x1/dep/font-awesome/4.0.3/less/font-awesome.css">\n    <!--[if IE 7]>\n        <link rel="stylesheet" href="http://uc-vs.bdimg.com/v3/20150603x1/dep/font-awesome/4.0.3/less/font-awesome-ie7.css">\n    <![e
# ...

# %%
# ?jar.set

# %%
jar = requests.cookies.RequestsCookieJar()
jar.set('BAIDUID', 'D0EF04595D7E8763F6C14DB86ABD40A7:FG=1', domain='.baidu.com', path='/')
jar.set('BDORZ', 'B490B5EBF6F3CD402E515D22BCDA1598', domain='.baidu.com', path='/')

jar.set('BDRCVFR[feWj1Vr5u3D]', 'I67x6TjHwwYf0', domain='.baidu.com', path='/')
jar.set('BDSFRCVID', '_kKsJeC62ZoOsW6AbgYK-VeW6HR2nZ3TH6aoATl712u40Kg2oMPcEG0Pqx8g0KubQWcXogKK0mOTHvbP', domain='.baidu.com', path='/')
jar.set('BDUSS', 'RsfjRqejBRRzBnekRLeH56REEwNHNhTXJibkdWZFpsWTBrWkdPWk1nYTd4bUJhQVFBQUFBJCQAAAAAAAAAAAEAAACLQycMenNzcGt4AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAALs5OVq7OTlab3', domain='.baidu.com', path='/')

jar.set('BIDUPSID', 'E822CD7B643FD7A34E8EF22E5AD79E18', domain='.baidu.com', path='/')
jar.set('FP_UID', '1c58f4660b0eb20c9eeedfcf2ad90087', domain='.baidu.com', path='/')
jar.set('H_BDCLCKID_SF', 'tR4jVCtbtIK3fP36qRbo-443qxby26PJ52ceaJ5nJDoShfIzM6bN-qLyjloEBn3htGQy_R6KQpP-HJ7bQ6QUb5kE54QvKfDOBmoOKl0MLPjlbb0xyn_V-U7ybMnMBMPjamOnaPQtLIFKhC-CDjDKDjPVbfQHh4J3K6PX3b7EfbcI8-O_bf--D4cLbHODtfoKQ67LL4cdbnQJOnnhy4bxy5K_hNjkQf7TJ4jm_I5D3CoOMqbHQT3mKt5bbN3i-4j825bUWb3cWKJV8UbS545me6jyeaDfqT-ff57-W6rb2nTJfJjkbPRq2DCShUFsXpJC-2Q-5KL--qbojI8RLtQ-LJ80247JKJODyg3Z_MbdJJjoShvM0fjAhqIEbbJlJlRia2TxoUJg5DnJhhvG-xRUybtebPRiJPr9Qgbq3ftLtD_-MKImjjD35n-WqxrJ5-oebPo2WDvhMlR5OR5Jj65AhnDWQnQC5tRJ2Dbl_UO9W-QosR3v3MA--t4SWh3q06oLbbve0CoOBlr4sq0x0bQWe-bQyPQaQlb2yIOMahkMal7xO-QP05CKD653eH8ttjnfb5kXB4bJK4OMKROkepnOyntpbt-qJqTyB57U_qjt5MTvKfQN3Tj106DHWGbnBT5Ka26nWI0httKMhhvTD4nY0-tkQN3TbRkO5bRiLRolQbOiDn3oyT3VXp0n5x5TqtJHKbDqoK05JMK', domain='.baidu.com', path='/')
jar.set('H_PS_PSSID', '1461_24886_21086_17001_22525_25177_20718', domain='.baidu.com', path='/')

jar.set('Hm_lpvt_4010fd5075fcfe46a16ec4cb65e02f04', '1513700181', domain='.i.baidu.com', path='/')
jar.set('Hm_lvt_4010fd5075fcfe46a16ec4cb65e02f04', '1513298663,1513699749', domain='.i.baidu.com', path='/')
jar.set('MCITY', '-%3A', domain='.baidu.com', path='/')
jar.set('PHPSESSID', 'tlmeih0p2huh2eats02r1slou3', domain='.i.baidu.com', path='/')
jar.set('PSINO', '2', domain='.baidu.com', path='/')
jar.set('PSTM', '1506721247', domain='.baidu.com', path='/')

url = 'http://i.baidu.com/'
r = requests.get(url, cookies=jar)
r.text
# Out:
# '<!doctype html>\r\n<html>\r\n<head>\r\n    <meta charset="UTF-8">\r\n    <!-- <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" /> -->\r\n    <title>百度个人中心——您在百度的家</title>\r\n    <meta name="description" content="百度个人中心是百度用户管理个性化信息的平台，在这里，您可以体验贴吧的交流、知道的解答、百科的全面、空间的个性、云盘的强大……感受百度为您带来的方便、快捷与乐趣。">\r\n    <meta name="keywords" content="个人中心,个人主页,个人帐号,个人空间">\r\n    <!--[if lt IE 7]>\r\n    <script>\r\n        window.location.href = \'http://i.baidu.com/static/ieup/index.html\';\r\n    </script>\r\n    <![endif]-->\r\n    <link rel="shortcut icon" type="image/ico" href="http://www.baidu.com/favicon.ico" />\r\n    <link rel="stylesheet" href="http://uc-vs.bdimg.com/v4/20160412x2/dep/font-awesome/4.0.3/less/font-awesome.css">\r\n    <!--[if IE 7]>\r\n        <link rel="stylesheet" href="http://uc-vs.bdimg.com/v4/20160412x2/dep/font-awesome/4.0.3/less/font-awesome-ie7.css">\r\n    <![endif]-->\r\n    <link rel="style
# ...

# %%
jar = requests.cookies.RequestsCookieJar()
jar.set('tasty_cookie', 'yum', domain='httpbin.org', path='/cookies')
jar.set('gross_cookie', 'blech', domain='httpbin.org', path='/elsewhere')
url = 'http://httpbin.org/cookies'
r = requests.get(url, cookies=jar)
r.text
# Out:
# '<!doctype html>\n<html>\n<head>\n    <meta charset="UTF-8">\n    <!-- <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" /> -->\n    <title>百度个人中心——您在百度的家</title>\n    <meta name="description" content="百度个人中心是百度用户管理个性化信息的平台，在这里，您可以体验贴吧的交流、知道的解答、百科的全面、空间的个性、云盘的强大……感受百度为您带来的方便、快捷与乐趣。">\n    <meta name="keywords" content="个人中心,个人主页,个人帐号,个人空间">\n    <meta name="baidu-site-verification" content="qo9ZiURIQf" />\n    <!--[if lt IE 7]>\n    <script>\n        window.location.href = \'http://i.baidu.com/static/ieup/index.html\';\n    </script>\n    <![endif]-->\n    <link rel="shortcut icon" type="image/ico" href="http://www.baidu.com/favicon.ico" />\n    <link rel="stylesheet" href="http://uc-vs.bdimg.com/v3/20150603x1/dep/font-awesome/4.0.3/less/font-awesome.css">\n    <!--[if IE 7]>\n        <link rel="stylesheet" href="http://uc-vs.bdimg.com/v3/20150603x1/dep/font-awesome/4.0.3/less/font-awesome-ie7.css">\n    <![e
# ...

# %%
requests.get('http://github.com', timeout=0.001)

# %% [markdown]
# ## tokend-based

# %%
r = requests.get('https://api.weibo.com/2/statuses/public_timeline.json?access_token=2.00d25mWB2vuYWC2cdf2f60c76qgGZC')

# %%
r.json()
# Out:
# {'hasvisible': False,
#  'interval': 0,
#  'next_cursor': 0,
#  'previous_cursor': 0,
#  'statuses': [{'annotations': [{'client_mblogid': 'iPhone-AF7C44CB-E3C8-499F-B06A-1A3D395E4232'},
#     {'mapi_request': True}],
#    'attitudes_count': 0,
#    'biz_feature': 4294967300,
#    'bmiddle_pic': 'http://wx4.sinaimg.cn/bmiddle/6d69a448gy1fmld6061gtj20qo0qojue.jpg',
#    'can_edit': False,
#    'comment_manage_info': {'approval_comment_type': 0,
#     'comment_permission_type': -1},
#    'comments_count': 0,
#    'created_at': 'Tue Dec 19 00:00:21 +0800 2017',
#    'darwin_tags': [],
#    'favorited': False,
#    'geo': None,
#    'gif_ids': '',
#    'hasActionTypeCard': 0,
#    'hot_weibo_tags': [],
#    'id': 4186457961211038,
#    'idstr': '4186457961211038',
#    'in_reply_to_screen_name': '',
#    'in_reply_to_status_id': '',
#    'in_reply_to_user_id': '',
#    'isLongText': False,
#    'is_paid': False,
#    'is_show_bulletin': 2,
#    'mblog_vip_type': 0,
# ...

# %% [markdown]
# ## 异步 aio

# %%
@asyncio.coroutine
def fetch(self, url):
    response = yield from self.session.get(url)
    body = yield from response.read()

# %%
import asyncio
from aiohttp import ClientSession

async def hello(url):
    async with ClientSession() as session:
        async with session.get(url) as response:
            response = await response.read()
            print(response)

loop = asyncio.get_event_loop()

loop.run_until_complete(hello("http://httpbin.org/headers"))
# Out:
# b'{\n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Connection": "close", \n    "Host": "httpbin.org", \n    "User-Agent": "Python/3.6 aiohttp/2.2.5"\n  }\n}\n'

# %%
for url in urls:
    print(requests.get(url).text)

# %%
loop = asyncio.get_event_loop()

tasks = []
# I'm using test server localhost, but you can use any url
url = "http://localhost:8080/{}"
for i in range(5):
    task = asyncio.ensure_future(hello(url.format(i)))
    tasks.append(task)
loop.run_until_complete(asyncio.wait(tasks))

# %%
import asyncio
from aiohttp import ClientSession

async def fetch(url, session):
    async with session.get(url) as response:
        return await response.read()

async def run(r):
    url = "http://localhost:8080/{}"
    tasks = []

    # Fetch all responses within one Client session,
    # keep connection alive for all requests.
    async with ClientSession() as session:
        for i in range(r):
            task = asyncio.ensure_future(fetch(url.format(i), session))
            tasks.append(task)

        responses = await asyncio.gather(*tasks)
        # you now have all response bodies in this variable
        print(responses)

def print_responses(result):
    print(result)

loop = asyncio.get_event_loop()
future = asyncio.ensure_future(run(4))
loop.run_until_complete(future)

# %%
class DowloadManager(object):
    def __init__(self, app):
        self.app = app

    async def download_task(self, session, rid, quality, url, full_path):
        chunk_size = 64 * 1024
        tries = 0
        while tries < 4:
            async with session.get(url, timeout=None) as response:
                if response.status >= 300:
#                    self.app.cacheproxy_logger.error("got error: HTTP Status {error},{headers}, history,{his}".format(
#                        error=response.status,
#                        headers=response.headers,
#                        his=response.history
#                    ))
                    return 0
                file_length = response.content_length
                os.makedirs(os.path.dirname(full_path), exist_ok=True)
                try:
                    download_size = 0
                    async with aiofiles.open(full_path, mode='wb') as f_handle:
                        async for data in response.content.iter_chunked(chunk_size):
                            await f_handle.write(data)
                            download_size += len(data)
                    await response.release()

                    return download_size
                except asyncio.CancelledError:
#                    self.app.cacheproxy_logger.error("got error:{error}".format(error=asyncio.CancelledError))
                    await response.release()
                    os.remove(full_path)
                    tries += 1
#        self.app.cacheproxy_logger.error("tried {times}, failed, please check connection".format(times=tries))
        return 0


    async def download_file(self, domain, rid, quality, url, path):
        request_headers = {
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
            'Connection': 'keep-alive',
            'Cache-Control': 'max-age=0',
            'User-Agent:': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_4) '
                           'AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36 ',
            'Accept-Encoding': 'gzip, deflate',
            'Accept-Language': 'en-US,en;q=0.8'}

        if domain:
            request_headers['Referer'] = domain
            #request_headers['Host'] = domain

        async with aiohttp.ClientSession(headers=request_headers) as session:
            download_size = await self.download_task(session, rid, quality, url, path)
        return download_size
